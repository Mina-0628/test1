# %%
#異常狀態處理try...except...語法
try:
    money=int(input("請輸入金額:"))
    print(f"輸入的金額是{money}") #f"string"格式化字串
except ValueError as e: #錯誤訊息為e這個變數
    print(f"輸入錯誤{e}")
# Out:
# 請輸入金額: 500a
# 輸入錯誤invalid literal for int() with base 10: '500a'
