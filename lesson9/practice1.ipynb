# %%
__name__
# Out:
# '__main__'

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 __file__
#
# NameError: name '__file__' is not defined

# %%
def main():
   print("我是專案檔執執行檔")

if __name__ == "__main__" :
   main()
# Out:
# 我是專案檔執執行檔

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import playwright
from playwright import sync_api
sync_api.sync_playwright()

# %%
#這個比較好
#先講好東西在哪裡（from 位置），把精確的工具拿出來（import 工具），需要時直接用它就對了！

from playwright.sync_api import sync_playwright
sync_playwright()

# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
with open("file1.txt") as file:
    content = file.read()
    print(content)
# Out:
# Hello!
